# %% [markdown]
# ### Extract Grantees' 990 Form

# %%
import pandas as pd
import numpy as np
import os
import glob
import re
import xml.etree.ElementTree as ET
import xmltodict
import urllib.request
import json
from pandas.io.json import json_normalize

# %%
# import 990 index file to connect EIN with S3 url
files = glob.glob('Z:/Projects/Grants/Data_Updates/990 Form/990_index_grantees/*.xlsx')
grantee990_index = {}
for f in files:
    grantee990_index[os.path.splitext(os.path.basename(f))[0].split('_')[-1]] = pd.read_excel(f).drop(['Unnamed: 0'], axis=1)

# %%
grantee990_index.keys()
# Out:
# dict_keys(['index13', 'index14', 'index15', 'index16', 'index17', 'index18'])

# %%
key_list = list(grantee990_index.keys())
for i in range(len(key_list)):
    print(key_list[i], grantee990_index[key_list[i]].shape)
# Out:
# index13 (16353, 8)
# index14 (16836, 8)
# index15 (16958, 8)
# index16 (15836, 8)
# index17 (16006, 8)
# index18 (8160, 8)

# %%
# check 
grantee990_index['index18'].shape
# Out:
# (8160, 8)

# %%
# pre-defined check function, return bool
def check_re(pat, S):
    return bool(re.search(pat, S))

# %%
# pre-define: col_info: pattern to use when parseing: nested list
# re-new: basic info added

colinfo = [["Filer", "EIN"],
           "TaxPeriodEndDt",
           "TaxYr",
           ["Filer", "BusinessNameLine1Txt"],
           ["Filer", "BusinessNameLine2Txt"],
           ["Filer", "BusinessNameControlTxt"],
           ["Filer", "CityNm"],
           ["Filer", "StateAbbreviationCd"],
           "ActivityOrMissionDesc",
           ["NetAssetsOrFundBalances", "EOYAmt"],
           "TotalAssetsEOYAmt",
           "CYTotalRevenueAmt", 
           "TotalLiabilitiesEOYAmt", 
           "CYTotalExpensesAmt",
           "CYContributionsGrantsAmt",
           ["CashNonInterestBearingGrp", "EOYAmt"],
           ["SavingsAndTempCashInvstGrp", "EOYAmt"],
           ["PledgesAndGrantsReceiveableGrp", "EOYAmt"],
           ["AccountsReceivableGrp", "EOYAmt"],
           ["ReceivablesFromOfficersEtcGrp", "EOYAmt"],
           ["RcvblFromDisqualifiedPrsnGrp", "EOYAmt"],
           ["OthNotesLoansReceivableNetGrp", "EOYAmt"],
           ["InventoriesForSaleOrUseGrp", "EOYAmt"],
           ["PrepaidExpensesDefrdChargesGrp", "EOYAmt"],
           "AccountsPayableAccrExpnssGrp",
           ["GrantsPayableGrp", "EOYAmt"],
           ["DeferredRevenueGrp", "EOYAmt"],
           ["EscrowAccountLiabilityGrp", "EOYAmt"],
           ["LoansFromOfficersDirectorsGrp", "EOYAmt"],
           ["OtherLiabilitiesGrp", "EOYAmt"],
           ["DepreciationDepletionGrp", "TotalAmt"],
           ["TotalFunctionalExpensesGrp", "ProgramServicesAmt"],
           "TotalGrossReceiptsAmt"
          ]

# %%
# function version 2: pass index-df instead of year
def retrieve_grantee990_dfv2(index_df):
    """
    input: index_df
    
    requirements: 990-grantees intersection index df
                  pre-defined check_re function return bool
                  pre-defined list of col info to use as pattern (regx)
    notes: 
    
    """
    #index_key = "index" + year[-2:]
    #index_df = grantee990_index[index_key]
    from xml.parsers.expat import ExpatError
    from urllib.error import URLError, HTTPError
    
    grantee_990df = pd.DataFrame()
    
    for x in index_df["URL"]:
        try:
            tree = ET.ElementTree(file=urllib.request.urlopen(x))
        except URLError:
            pass
        
        root = tree.getroot()
        xmlstr = ET.tostring(root, encoding='utf8', method='xml')
        
        try:
            row = json_normalize(dict(xmltodict.parse(xmlstr)))
        except ExpatError:
            pass
        
        # select columns: ANY
        ## re.search pattern
        bool_df = pd.DataFrame()
        for i in colinfo:
            if type(i) == str:
                pat = "(?=.*{})".format(i)              
            else:
                pat = ''
                for j in i:
                    a = "(?=.*{})".format(j)
                    pat = pat + a
            
            # return bool for re.search
            bool_row = [check_re(pat, col) for col in list(row.columns)]
            bool_df = pd.concat([bool_df, pd.Series(bool_row)], axis=1)
            
        boolfilter = bool_df.any(axis=1).tolist() # row-wise
        
        row_filtered = row.iloc[:, bool_df.loc[boolfilter, :].index]
        grantee_990df = pd.concat([grantee_990df, row_filtered], axis=0)
    
    return grantee_990df

# %%
index_df18_3000 = grantee990_index["index18"].iloc[:3000, ]
grantee990_18_3000 = retrieve_grantee990_dfv2(index_df18_3000)
print(grantee990_18_3000.shape)
# Out:
# (3000, 38)

# %%
pd.options.display.max_columns = 40
grantee990_18_3000[:5]
# Out:
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:AccountsPayableAccrExpnssGrp.ns0:BOYAmt  \
# 0                                           12140407
# 0                                            1213110
# 0                                             686587
# 0                                            3363767
# 0                                             205520
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:AccountsPayableAccrExpnssGrp.ns0:EOYAmt  \
# 0                                           12814147
# 0                                             864269
# 0                                             575400
# 0                                            3597523
# 0                                             548456
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:AccountsReceivableGrp.ns0:EOYAmt  \
# 0                                            5363939
# 0                                            1556674
# 0                                                NaN
# 0                                            5452474
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:ActivityOrMissionDesc  \
# 0  TO CREATE PUBLIC SCHOOLS THAT EQUIP EDUCATIONA...
# 0  TO PROVIDE SOCIAL SERVICES FOR THE NEEDS OF IN...
# 0  TO PROVIDE HOLISTIC AND CLIENT CENTERED SERVIC...
# 0  TO STRENGTHEN AND PRESERVE HEALTHY KINSHIP FAM...
# 0  DEVELOPING THE CAPACITY OF STUDENTS TO BE SUCC...
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:CYContributionsGrantsAmt  \
# 0                                           62815001
# 0                                           17133526
# 0                                            4618043
# 0                                           36803527
# 0                                           11533635
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:CYTotalExpensesAmt  \
# 0                                           73827353
# 0                                           17889434
# 0                                           11193181
# 0                                           36853394
# 0                                           12506034
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:CYTotalRevenueAmt  \
# 0                                           69907277
# 0                                           18884881
# 0                                           11409331
# 0                                           36803893
# 0                                           13281543
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:CashNonInterestBearingGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                            1864325
# 0                                            1046674
# 0                                               1495
# 0                                            1012871
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:DeferredRevenueGrp.ns0:EOYAmt  \
# 0                                              95225
# 0                                                NaN
# 0                                                NaN
# 0                                             325000
# 0                                              61132
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:DepreciationDepletionGrp.ns0:TotalAmt  \
# 0                                             845278
# 0                                              69628
# 0                                             382417
# 0                                             294095
# 0                                             117587
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:EscrowAccountLiabilityGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:GrantsPayableGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:InventoriesForSaleOrUseGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                  0
# 0                                               2000
# 0                                               5703
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:LoansFromOfficersDirectorsGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:NetAssetsOrFundBalancesEOYAmt  \
# 0                                           50178621
# 0                                            1027228
# 0                                            6715445
# 0                                            4081056
# 0                                            2914902
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:OthNotesLoansReceivableNetGrp.ns0:EOYAmt  \
# 0                                            2024157
# 0                                                  0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:OtherLiabilitiesGrp.ns0:EOYAmt  \
# 0                                            7377370
# 0                                            1853902
# 0                                                NaN
# 0                                                NaN
# 0                                             126956
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:PrepaidExpensesDefrdChargesGrp.ns0:EOYAmt  \
# 0                                             457160
# 0                                                  0
# 0                                              89807
# 0                                             262547
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:RcvblFromDisqualifiedPrsnGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                  0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:ReceivablesFromOfficersEtcGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                  0
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:SavingsAndTempCashInvstGrp.ns0:EOYAmt  \
# 0                                           30189412
# 0                                                  0
# 0                                             439640
# 0                                               3269
# 0                                             432657
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:TotalAssetsEOYAmt  \
# 0                                           70465363
# 0                                            3895399
# 0                                            9279644
# 0                                            8641307
# 0                                            3651446
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:TotalFunctionalExpensesGrp.ns0:ProgramServicesAmt  \
# 0                                           61066951
# 0                                           16579254
# 0                                            9234898
# 0                                           30607734
# 0                                           11128161
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990.ns0:TotalLiabilitiesEOYAmt  \
# 0                                           20286742
# 0                                            2868171
# 0                                            2564199
# 0                                            4560251
# 0                                             736544
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990EZ.ns0:NetAssetsOrFundBalancesEOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990EZ.ns0:NetAssetsOrFundBalancesGrp.ns0:EOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990PF.ns0:Form990PFBalanceSheetsGrp.ns0:TotalAssetsEOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990PF.ns0:Form990PFBalanceSheetsGrp.ns0:TotalLiabilitiesEOYAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnData.ns0:IRS990ScheduleG.ns0:TotalGrossReceiptsAmt  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:BusinessName.ns0:BusinessNameLine1Txt  \
# 0                                    KIPP FOUNDATION
# 0                      CATHOLIC FAMILY AND COMMUNITY
# 0                        ODYSSEY HOUSE LOUISIANA INC
# 0                                A SECOND CHANCE INC
# 0                                      PRO-YOUTH INC
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:BusinessName.ns0:BusinessNameLine2Txt  \
# 0                                                NaN
# 0                                       SERVICES INC
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:BusinessNameControlTxt  \
# 0                                               KIPP
# 0                                               CATH
# 0                                               ODYS
# 0                                               ASEC
# 0                                               PRO-
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:EIN  \
# 0                                     943362724
# 0                                     221487121
# 0                                     720743677
# 0                                     251729710
# 0                                     770337714
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:ForeignAddress.ns0:CityNm  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:USAddress.ns0:CityNm  \
# 0                                      SAN FRANCISCO
# 0                                           PATERSON
# 0                                        NEW ORLEANS
# 0                                         PITTSBURGH
# 0                                            VISALIA
#
#   ns0:Return.ns0:ReturnHeader.ns0:Filer.ns0:USAddress.ns0:StateAbbreviationCd  \
# 0                                                 CA
# 0                                                 NJ
# 0                                                 LA
# 0                                                 PA
# 0                                                 CA
#
#   ns0:Return.ns0:ReturnHeader.ns0:TaxPeriodEndDt  \
# 0                                     2018-06-30
# 0                                     2018-06-30
# 0                                     2018-06-30
# 0                                     2018-06-30
# 0                                     2018-06-30
#
#   ns0:Return.ns0:ReturnHeader.ns0:TaxYr
# 0                                  2017
# 0                                  2017
# 0                                  2017
# 0                                  2017
# 0                                  2017

# %%
bool_df = pd.DataFrame()
for i in colinfo:
    if type(i) == str:
        pat = "(?=.*{})".format(i)              
    else:
        pat = ''
        for j in i:
            a = "(?=.*{})".format(j)
            pat = pat + a
    print(pat)
# return bool for re.search
    bool_row = [check_re(pat, col) for col in list(grantee990_18_100.columns)]
    bool_df = pd.concat([bool_df, pd.Series(bool_row)], axis=1)
boolfilter = bool_df.any(axis=1).tolist() # row-wise
# Out:
# (?=.*NetAssetsOrFundBalances)(?=.*EOYAmt)
# (?=.*TotalAssets)(?=.*EOYAmt)
# (?=.*CYTotalRevenueAmt)
# (?=.*TotalLiabilities)(?=.*EOYAmt)
# (?=.*CYTotalExpensesAmt)
# (?=.*CYContributionsGrantsAmt)
# (?=.*CashNonInterestBearingGrp)(?=.*EOYAmt)
# (?=.*SavingsAndTempCashInvstGrp)(?=.*EOYAmt)
# (?=.*PledgesAndGrantsReceiveableGrp)(?=.*EOYAmt)
# (?=.*AccountsReceivableGrp)(?=.*EOYAmt)
# (?=.*ReceivablesFromOfficersEtcGrp)(?=.*EOYAmt)
# (?=.*RcvblFromDisqualifiedPrsnGrp)(?=.*EOYAmt)
# (?=.*OthNotesLoansReceivableNetGrp)(?=.*EOYAmt)
# (?=.*InventoriesForSaleOrUseGrp)(?=.*EOYAmt)
# (?=.*PrepaidExpensesDefrdChargesGrp)(?=.*EOYAmt)
# (?=.*AccountsPayableAccrExpnssGrp)
# (?=.*GrantsPayableGrp)(?=.*EOYAmt)
# (?=.*DeferredRevenueGrp)(?=.*EOYAmt)
# (?=.*EscrowAccountLiabilityGrp)(?=.*EOYAmt)
# (?=.*LoansFromOfficersDirectorsGrp)(?=.*EOYAmt)
# (?=.*OtherLiabilitiesGrp)(?=.*EOYAmt)
# (?=.*DepreciationDepletionGrp)(?=.*TotalAmt)
# (?=.*TotalFunctionalExpensesGrp)(?=.*ProgramServicesAmt)

# %%
pat = '(?=.*AccountsReceivableGrp)(?=.*EOYAmt)'
pat = "(?=.*{})(?=.*{})".format(colinfo[1][0], colinfo[1][1])

for i in colinfo:
    if type(i) == str:
        pat = "(?=.*{})".format(i)
        print(pat)
              
    else:
        a = ''
        for j in i:
            pat = "(?=.*{})".format(j)
            a = a + pat
            print(a)

# %%
df_try = pd.DataFrame()
for x in sample['URL']:
    tree = ET.ElementTree(file=urllib.request.urlopen(x))
    root = tree.getroot()
    xmlstr = ET.tostring(root, encoding='utf8', method='xml')
    df_append = json_normalize(dict(xmltodict.parse(xmlstr)))
    
    df_try = pd.concat([df_try, df_append], axis=0)
